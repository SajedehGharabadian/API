# %%
import requests
import json
import dotenv
import os

# %%
dotenv = dotenv.load_dotenv()

# %% [markdown]
# ## The Lord of the Rings

# %%
LTR_API = os.getenv("LTR_API")

headers = {
    "Authorization":LTR_API
}


response = requests.get('https://the-one-api.dev/v2/movie',headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'docs': [{'_id': '5cd95395de30eff6ebccde56',
#    'name': 'The Lord of the Rings Series',
#    'runtimeInMinutes': 558,
#    'budgetInMillions': 281,
#    'boxOfficeRevenueInMillions': 2917,
#    'academyAwardNominations': 30,
#    'academyAwardWins': 17,
#    'rottenTomatoesScore': 94},
#   {'_id': '5cd95395de30eff6ebccde57',
#    'name': 'The Hobbit Series',
#    'runtimeInMinutes': 462,
#    'budgetInMillions': 675,
#    'boxOfficeRevenueInMillions': 2932,
#    'academyAwardNominations': 7,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 66.33333333},
#   {'_id': '5cd95395de30eff6ebccde58',
#    'name': 'The Unexpected Journey',
#    'runtimeInMinutes': 169,
#    'budgetInMillions': 200,
#    'boxOfficeRevenueInMillions': 1021,
#    'academyAwardNominations': 3,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 64},
#   {'_id': '5cd95395de30eff6ebccde59',
#    'name': 'The Desolation of Smaug',
#    'runtimeInMinutes': 161,
#    'budgetInMillions': 217,
# ...

# %% [markdown]
# ## Icon Finder

# %%
url = "https://api.iconfinder.com/v4/icons/search?query=arrow&count=10"

ICONFINDER_API = os.getenv("ICONFINDER_API")


headers = {
    "accept": "application/json",
    "Authorization": ICONFINDER_API
}
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'total_count': 189279,
#  'icons': [{'icon_id': 4470662,
#    'tags': ['app', 'back', 'mobile', 'ui', 'ux', 'web', 'arrow'],
#    'published_at': '2019-04-05T08:53:39.350522',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
# ...

# %% [markdown]
# ## Illusion Diffusion

# %%
url = 'https://fal.run/fal-ai/illusion-diffusion'

ILLUSIONDIFFUSION_API = os.getenv("ILLUSIONDIFFUSION_API")

headers = {
    "Authorization" : ILLUSIONDIFFUSION_API,
    "Content-Type": "application/json"
}
payload = {
    "image_url": "https://storage.googleapis.com/falserverless/illusion-examples/turkey-flag.png",
    "prompt": "(masterpiece:1.4), (best quality), (detailed),landscape,A tiger hunt the bear in the sea",
    "Negative Prompt":"(worst quality, poor details:1.4), lowres, (artist name, signature, watermark:1.4), bad-artist-anime, bad_prompt_version2, bad-hands-5, ng_deepnegative_v1_75t"
}

response = requests.post(url,headers=headers,json=payload)
response.status_code

# %%
response.json()
# Out:
# {'image': {'url': 'https://storage.googleapis.com/isolate-dev-hot-rooster_toolkit_bucket/d1488359687a4dd18c1f09fb25972476.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-service-account%40isolate-dev-hot-rooster.iam.gserviceaccount.com%2F20240313%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240313T131936Z&X-Goog-Expires=604800&X-Goog-SignedHeaders=host&X-Goog-Signature=...',
#   'content_type': 'image/png',
#   'file_name': 'b6e8294dea504da2bc15aee0fb681412.png',
#   'file_size': 1745601,
#   'width': 1024,
#   'height': 1024},
#  'seed': 5569894757128132}

# %% [markdown]
# ## D-ID

# %%
url = "https://api.d-id.com/clips"

DID_API = os.getenv("DID_API")

payload = {
    "script": {
        "type": "text",
        "provider": {
            "type": "microsoft",
            "voice_id": "en-US-JennyNeural"
        },
        "ssml": "false",
        "input": "Hey guys, how is going every thing?"
    },
    "config": { "result_format": "mp4" },
    "presenter_config": { "crop": { "type": "wide" } },
    "background": { "color": "false" },
    "presenter_id": "anita-6_uTzyZtNR"
}

headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": DID_API

}
response = requests.post(url, json=payload, headers=headers)
response.status_code
# Out:
# 201

# %%
response.json()
# Out:
# {'id': 'clp_7uz6q1-xUAIWXQttikNxZ',
#  'created_at': '2024-03-12T18:21:23.522Z',
#  'object': 'clip',
#  'status': 'created'}

# %%
url = "https://api.d-id.com/clips/clp_7uz6q1-xUAIWXQttikNxZ"

headers = {
    "accept": "application/json",
    "authorization": DID_API
}

response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'script': {'length': 35,
#   'ssml': False,
#   'subtitles': False,
#   'type': 'text',
#   'provider': {'type': 'microsoft', 'voice_id': 'en-US-JennyNeural'}},
#  'metadata': {'num_frames': 71,
#   'processing_fps': 18.291289559100058,
#   'resolution': [1080, 1080],
#   'size_kib': 3641.4697265625},
#  'audio_url': 'https://d-id-clips-prod.s3.us-west-2.amazonaws.com/google-oauth2%7C113038932932397148140/clp_7uz6q1-xUAIWXQttikNxZ/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIJ7CPKJNP&Expires=1710354083&Signature=uYxL9pLC88nWbdiyG5sdgzm9E1s%3D',
#  'created_at': '2024-03-12T18:21:23.522Z',
#  'config': {'logo': {'url': 'https://d-id-user-logos-prod.s3.us-west-2.amazonaws.com/default/worker/did-watermark-2023.png',
#    'position': [0, 0]},
#   'result_format': '.mp4',
#   'fluent': False,
#   'motion_factor_kp': [1, 0.75]},
#  'source_url': 'https://clips-presenters.d-id.com/anita/6_uTzyZtNR/Ecg7Fd7cJz/thumbnail.png',
#  'created_by': 'google-oauth2|113038932932397148140',
# ...

# %% [markdown]
# ## Planet

# %%
url = "https://my-api.plantnet.org/v2/identify/all"

PLANT_API = os.getenv("PLANT_API")

headers = {}

payload = {
    "api-key": PLANT_API
}
files = {
    "images":open('/content/abrishami.jpg',"rb")
}
response = requests.post(url, headers=headers,params=payload,files=files)

response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'query': {'project': 'all',
#   'images': ['3f1078eba2e5d51e81aa5ecdbfdefbd2'],
#   'organs': ['auto'],
#   'includeRelatedImages': False,
#   'noReject': False},
#  'language': 'en',
#  'preferedReferential': 'k-world-flora',
#  'bestMatch': 'Albizia lebbeck (L.) Benth.',
#  'results': [{'score': 0.76287,
#    'species': {'scientificNameWithoutAuthor': 'Albizia lebbeck',
#     'scientificNameAuthorship': '(L.) Benth.',
#     'genus': {'scientificNameWithoutAuthor': 'Albizia',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Albizia'},
#     'family': {'scientificNameWithoutAuthor': 'Fabaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Fabaceae'},
#     'commonNames': ['Siris tree', 'Broome raintree', 'East Indian-walnut'],
#     'scientificName': 'Albizia lebbeck (L.) Benth.'},
#    'gbif': {'id': '2973215'},
#    'powo': {'id': '99109-3'},
#    'iucn': {'id': '18435916', 'category': 'LC'}},
#   {'score': 0.00772,
# ...
